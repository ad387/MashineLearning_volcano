# %% [markdown]
# # find stations in location of interest

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
client = Client("IRIS")

lat_0 = 0
lon_0 = -85
lat_1 = -5
lon_2 = -75

# inventory  = client.get_stations(minlatitude = -2, 
#                                  maxlatitude = 0, 
#                                  minlongitude = -80, 
#                                  maxlongitude = -77 )

inv  = client.get_stations()

# %%
inv = client.get_stations(network="IU", 
                          level="channel")

# %%
inv
# Out:
# Inventory created at 2017-05-02T11:32:48.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.25
# 		    http://service.iris.edu/fdsnws/station/1/query?level=channel&networ...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			IU
# 		Stations (269):
# 			IU.AAE (Addis Ababa, Ethiopia)
# 			IU.AAE1 (Addis Ababa, Ethiopia)
# 			IU.ADK (Adak, Aleutian Islands, Alaska)
# 			IU.ADK (Adak, Aleutian Islands, Alaska)
# 			IU.ADK (Adak, Aleutian Islands, Alaska)
# 			IU.AFI (Afiamalu, Samoa)
# 			IU.AFI (Afiamalu, Samoa)
# 			IU.AFI (Afiamalu, Samoa)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANMO (Albuquerque, New Mexico, USA)
# 			IU.ANTO (Ankara, Turkey)
# 			IU.ANTO (Ankara, Turkey)
# 			IU.ANTO (Ankara, Turkey)
# 			IU.ANTO (Ankara, Turkey)
# ...

# %%
t = UTCDateTime("2016-02-27T06:45:00.000")

# %%
st = client.get_waveforms("IU", "OTAV", "00", "BH2", t, t + 60 * 1)

# %%
st.
