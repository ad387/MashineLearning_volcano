# %%
import numpy as np

# %%
import obspy
# Out:
# /net/hciserver03/storage/oblum/bibs/venv_new/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from obspy import read

# %%
st = read('http://examples.obspy.org/RJOB_061005_072159.ehz.new')
print(st)
# Out:
# 1 Trace(s) in Stream:
# .RJOB..Z | 2005-10-06T07:21:59.850000Z - 2005-10-06T07:24:59.845000Z | 200.0 Hz, 36000 samples

# %%
st.plot()

# %%
from obspy.clients.fdsn import Client
# Out:
# /net/hciserver03/storage/oblum/python/data/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
client = Client("IRIS")

# %%
from obspy import UTCDateTime

# %%
t = UTCDateTime("2010-02-27T06:45:00.000")

# %%
st = client.get_waveforms("IU", "ANMO", "00", "LHZ", t, t + 60 * 60)

# %%
st.plot()

# %% [markdown]
# # find stations in location of interest

# %%
from obspy.clients.fdsn import Client
# Out:
# /net/hciserver03/storage/oblum/python/data/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
client = Client("IRIS")

lat_0 = 0
lon_0 = -85
lat_1 = -5
lon_2 = -75

# inventory  = client.get_stations(minlatitude = -2, 
#                                  maxlatitude = 0, 
#                                  minlongitude = -80, 
#                                  maxlongitude = -77 )

inventory  = client.get_stations(=

# %%
inventory.get_contents()
# Out:
# {u'channels': [],
#  u'networks': [u'8G', u'EC', u'YO'],
#  u'stations': [u'8G.EC07 (EC07)',
#   u'8G.EC08 (EC08)',
#   u'8G.EC17 (EC17)',
#   u'EC.ANTS (OVANTI_S)',
#   u'EC.CHSH (OVCHIM_S)',
#   u'EC.GGPC (OVPICH_S)',
#   u'EC.PORT (OVCHIM_S)',
#   u'EC.PUYO (RENSIG)',
#   u'EC.SAGO (Sagoatoa, Ambato, Ecuador)',
#   u'EC.SLOR (TEMP - COTO)',
#   u'EC.VCES (RENSIG)',
#   u'YO.TBAG (Banos, Tungurahua, Ecuador)',
#   u'YO.TBUG (Banos, Tungurahua, Ecuador)',
#   u'YO.TGRS (Banos, Tungurahua, Ecuador)',
#   u'YO.TLAV (Banos, Tungurahua, Ecuador)',
#   u'YO.TLEF (Banos, Tungurahua, Ecuador)',
#   u'YO.TMAR (Banos, Tungurahua, Ecuador)',
#   u'YO.TREX (Banos, Tungurahua, Ecuador)']}

# %% [markdown]
# # get waveform at date of interest

# %%
from obspy import UTCDateTime
t = UTCDateTime("2010-02-27T06:45:00.000")

# %%
st = client.get_waveforms("YO", "TBAG", "00", "LHZ", t, t + 60 * 60)
# Out:
# ---------------------------------------------------------------------------
# FDSNException                             Traceback (most recent call last)
# <ipython-input-11-d686faef5dd5> in <module>()
# ----> 1 st = client.get_waveforms("YO", "TBAG", "00", "LHZ", t, t + 60 * 60)
#
# /net/hciserver03/storage/oblum/python/data/venv/local/lib/python2.7/site-packages/obspy/clients/fdsn/client.pyc in get_waveforms(self, network, station, location, channel, starttime, endtime, quality, minimumlength, longestonly, filename, attach_response, **kwargs)
#     734         # Gzip not worth it for MiniSEED and most likely disabled for this
#     735         # route in any case.
# --> 736         data_stream = self._download(url, use_gzip=False)
#     737         data_stream.seek(0, 0)
#     738         if filename:
#
# /net/hciserver03/storage/oblum/python/data/venv/local/lib/python2.7/site-packages/obspy/clients/fdsn/client.pyc in _download(self, url, return_string, data, use_gzip)
# ...
