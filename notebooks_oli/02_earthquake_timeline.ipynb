# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from data_earthquake import Earthquake
import visualize

# %% [markdown]
# # get eathquake data

# %%
loc = (-1.470457, -78.448947)
t_beg = (2013, 1, 1)
t_end = (2018, 1, 1)
eq_tungurahua = Earthquake(loc, t_beg = t_beg, t_end = t_end)
# Out:
# load events 'data/earthquakes/(-1.470457, -78.448947)_1.0_1.0.npy' ...
# loaded 94 events

# %% [markdown]
# # plot data

# %%
visualize.show_earthquake_timeline(eq_tungurahua.dates, eq_tungurahua.mags)

# %% [markdown]
# # get frequency

# %%
eq_tungurahua.get_frequency_nearest()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-abdebfa4af99> in <module>()
# ----> 1 eq_tungurahua.get_frequency_nearest()
#
# /net/hciserver03/storage/oblum/projects/MashineLearning_volcano/data_earthquake.pyc in get_frequency_nearest(self)
#     172         # self.dates...
#     173
# --> 174         return dates, freq
#     175
#     176
#
# NameError: global name 'dates' is not defined
