# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

from visualize import disp
import visualize
from data_so2_sat import SO2_Sat

# %% [markdown]
# # so2 class

# %%
loc = (-1.470457, -78.448947)
t_beg = (2015, 1, 1)
t_end = (2015, 2, 1)
so2 = SO2_Sat(loc, t_beg, t_end)

# %%
visualize.show_so2_sat_timeline(so2.dates, so2.so2_timeseq['SO2_TRL'])
