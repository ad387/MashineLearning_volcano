# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

from visualize import disp
import visualize
from parsing import parse_so2_sat

# %% [markdown]
# # load single date

# %%
pos  = (-1.468450, -78.447024)
date = (2015,1,1)

# %%
vals = parse_so2_sat.get_pos_of_interest(date, pos)

# %%
vals
# Out:
# {'SO2_PBL': 2.0599817363545299,
#  'SO2_STL': 0.12363959196954966,
#  'SO2_TRL': 0.14568612771108747,
#  'SO2_TRM': 0.11311933025717735,
#  'SO2_TRU': 0.13764021219685674}

# %% [markdown]
# # load timeseries

# %%
time_sequence, dates = parse_so2_sat.get_time_sequence(pos,
                                                       date_beg=(2012,1,1), 
                                                       date_end=(2013,1,1))
# Out:
#   0%|          | 0/366 [00:00<?, ?it/s]parsing/parse_so2_sat.py:133: RuntimeWarning: Mean of empty slice.
#   if mode == "mean":
# 100%|██████████| 366/366 [04:00<00:00,  1.49it/s]

# %%
visualize.show_so2_sat_timeline(dates, time_sequence['SO2_TRL'])

# %%
time_sequence, dates = parse_so2_sat.get_time_sequence(pos,
                                                       date_beg=(2015,1,1), 
                                                       date_end=(2015,2,1))
# Out:
# 100%|██████████| 31/31 [13:02<00:00, 23.58s/it]

# %%
visualize.show_so2_sat_timeline(dates, time_sequence['SO2_TRL'])
