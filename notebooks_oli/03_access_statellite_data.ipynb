# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

from visualize import disp
import visualize
import data_so2_sat

# %% [markdown]
# # load single date

# %%
pos  = (-1.468450, -78.447024)
date = (2015,1,1)

# %%
vals = data_so2_sat.get_pos_of_interest(date, pos)

# %%
vals
# Out:
# {'SO2_PBL': 2.0599817363545299,
#  'SO2_STL': 0.12363959196954966,
#  'SO2_TRL': 0.14568612771108747,
#  'SO2_TRM': 0.11311933025717735,
#  'SO2_TRU': 0.13764021219685674}

# %% [markdown]
# # load timeseries

# %%
time_sequence, dates = data_so2_sat.get_time_sequence(pos,
                                                       date_beg=(2016, 1, 1), 
                                                       date_end=(2017, 1, 1))
# Out:
# 100%|██████████| 366/366 [05:29<00:00,  1.14s/it]

# %%
visualize.show_so2_sat_timeline(dates, time_sequence['SO2_TRL'])

# %% [markdown]
# # save time series

# %%
data = {}
data["dates"] = dates
data["vals"] = time_sequence

# %%
data = np.array(data)

# %%
np.save("data_git/SO2_sat/tungurahua_sum.npy", data)
